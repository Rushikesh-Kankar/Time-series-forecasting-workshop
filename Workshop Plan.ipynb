# %% [markdown]
# # ML-Pipeline for Time Series Data
#
#
# -- Introduction to Dataset
# - Time Series Data
# - Features
# - Walmart Dataset
# - Goal
#
# -- Exploratory Data Analysis
# - Corelations
# - Patttern
# - Visulization
#
# -- Data Prepartion + Data Preprocessing
# - ETL
# - Filtering
# - Feature engineering
#
# -- Model Training
# - Into to few relevant models
# - Comparison with SVM
#
#
# -- Prediction
# - ML Scoring (RMS, F1 (why-not-to-use-here))
# - Evaluation
# - Used techniaques vs. baseline (SVM)
#
#
# - Total 5 modules
#
# ## Prep Step
#
# 1. Wednesday Add code to the modules with basic text/comments
#
# 2. write references at the end of each module/further reading
#
# 3. Appendix
# -  Include help funtion ect..

# %% [markdown]
# Prereq:
# 1) Familiatity with Pandas
# 2)
